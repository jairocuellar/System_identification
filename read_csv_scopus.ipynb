# %%
from sympy import MatrixSymbol, Matrix, Identity

import sympy as sym
import pandas as pd
import math

sym.init_printing()
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import control
import random

# %%
datos = pd.read_csv ('data\low3.csv')
datos

datos.t1 = 1000*datos.t1

plt.plot(datos.t1,datos.y,color = 'red')
plt.plot(datos.t1,datos.u,color = 'blue')
